# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pet = pd.read_csv("pet_adoption_data.csv")

# %%
pet2 = pd.DataFrame(pet)
pet2
# Out:
#       PetID PetType             Breed  AgeMonths   Color    Size   WeightKg  \
# 0       500    Bird          Parakeet        131  Orange   Large   5.039768
# 1       501  Rabbit            Rabbit         73   White   Large  16.086727
# 2       502     Dog  Golden Retriever        136  Orange  Medium   2.076286
# 3       503    Bird          Parakeet         97   White   Small   3.339423
# 4       504  Rabbit            Rabbit        123    Gray   Large  20.498100
# ...     ...     ...               ...        ...     ...     ...        ...
# 2002   2502     Dog            Poodle         72  Orange   Small  27.039045
# 2003   2503  Rabbit            Rabbit        124   Brown   Small   4.726954
# 2004   2504  Rabbit            Rabbit        113  Orange   Small   1.758592
# 2005   2505     Dog          Labrador         12    Gray   Large  20.961592
# 2006   2506  Rabbit            Rabbit        126   White  Medium  18.519788
#
# ...

# %%
pet.head()
# Out:
#    PetID PetType             Breed  AgeMonths   Color    Size   WeightKg  \
# 0    500    Bird          Parakeet        131  Orange   Large   5.039768
# 1    501  Rabbit            Rabbit         73   White   Large  16.086727
# 2    502     Dog  Golden Retriever        136  Orange  Medium   2.076286
# 3    503    Bird          Parakeet         97   White   Small   3.339423
# 4    504  Rabbit            Rabbit        123    Gray   Large  20.498100
#
#    Vaccinated  HealthCondition  TimeInShelterDays  AdoptionFee  PreviousOwner  \
# 0           1                0                 27          140              0
# 1           0                0                  8          235              0
# 2           0                0                 85          385              0
# 3           0                0                 61          217              1
# 4           0                0                 28           14              1
#
#    AdoptionLikelihood
# 0                   0
# ...

# %%
pet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2007 entries, 0 to 2006
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PetID               2007 non-null   int64
#  1   PetType             2007 non-null   object
#  2   Breed               2007 non-null   object
#  3   AgeMonths           2007 non-null   int64
#  4   Color               2007 non-null   object
#  5   Size                2007 non-null   object
#  6   WeightKg            2007 non-null   float64
#  7   Vaccinated          2007 non-null   int64
#  8   HealthCondition     2007 non-null   int64
#  9   TimeInShelterDays   2007 non-null   int64
#  10  AdoptionFee         2007 non-null   int64
#  11  PreviousOwner       2007 non-null   int64
#  12  AdoptionLikelihood  2007 non-null   int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 204.0+ KB

# %%
pet["PetType"][]
# Out:
# 'Dog'

# %%
bird = []
dog = []
cat = []
rabbit = []
for lines in range(2006):
    if pet["PetType"][lines] == "Rabbit":
        rabbit.append(lines)
    elif pet["PetType"][lines] == "Dog":
        dog.append(lines)
    elif pet["PetType"][lines] == "Cat":
        cat.append(lines)
    elif pet["PetType"][lines] == "Bird":
        bird.append(lines)
    else:
        print("hello")

# %%
print(rabbit)
# Out:
# [1, 4, 11, 15, 18, 20, 27, 28, 29, 34, 36, 37, 48, 49, 51, 53, 57, 59, 66, 70, 72, 74, 76, 86, 87, 88, 98, 105, 106, 120, 123, 126, 127, 134, 143, 144, 145, 146, 149, 151, 157, 167, 171, 172, 176, 189, 192, 195, 203, 204, 206, 210, 211, 213, 218, 219, 221, 223, 224, 228, 235, 236, 240, 243, 249, 250, 252, 253, 257, 258, 260, 268, 270, 273, 274, 275, 276, 277, 281, 282, 295, 297, 299, 301, 303, 305, 306, 310, 312, 317, 320, 323, 328, 337, 346, 350, 352, 357, 359, 371, 373, 376, 378, 379, 383, 384, 385, 387, 392, 404, 407, 409, 414, 423, 427, 433, 442, 443, 444, 446, 447, 448, 450, 456, 458, 460, 467, 473, 481, 482, 485, 486, 489, 490, 500, 506, 508, 510, 511, 514, 517, 521, 533, 539, 546, 547, 553, 554, 568, 569, 570, 576, 578, 586, 589, 598, 601, 603, 604, 606, 607, 609, 610, 614, 616, 617, 622, 628, 636, 639, 652, 668, 671, 673, 681, 685, 696, 707, 712, 720, 726, 730, 731, 732, 733, 734, 736, 749, 758, 761, 769, 777, 785, 791, 801, 805, 809, 810, 814, 817, 825, 826, 830, 836, 839, 8
# ...

# %%
bird2 = []
dog2 = []
cat2 = []
rabbit2 = []
birdtime = []
dogtime = []
cattime = []
rabbittime = []
for lines in range(2006):
    if pet["PetType"][lines] == "Rabbit":
        rabbit2.append(pet["Color"][lines])
        rabbittime.append(pet["TimeInShelterDays"][lines])
    elif pet["PetType"][lines] == "Dog":
        dog2.append(pet["Color"][lines])
        dogtime.append(pet["TimeInShelterDays"][lines])
    elif pet["PetType"][lines] == "Cat":
        cat2.append(pet["Color"][lines])
        cattime.append(pet["TimeInShelterDays"][lines])
    elif pet["PetType"][lines] == "Bird":
        bird2.append(pet["Color"][lines])
        birdtime.append(pet["TimeInShelterDays"][lines])

# %%
# Your code here

plt.bar(rabbit2, rabbittime) # the greatest plot ever
plt.xlabel('color of rabbit')
plt.ylabel('time in sheltr')
plt.title('color vs tim in shelter') # this is the title
plt.show()

# %%
# Your code here

plt.bar(dog2, dogtime) # the greatest plot ever
plt.xlabel('color of rabbit')
plt.ylabel('time in sheltr')
plt.title('color vs tim in shelter') # this is the title
plt.show()

# %%
print(dog2[58])
# Out:
# Black

# %%
print(dog2)
print(dogtime)
# Out:
# ['Orange', 'Brown', 'Brown', 'Gray', 'Gray', 'White', 'Gray', 'Brown', 'Black', 'Brown', 'White', 'Brown', 'White', 'Black', 'Brown', 'White', 'Gray', 'White', 'Black', 'Orange', 'Gray', 'White', 'Orange', 'White', 'Gray', 'Brown', 'Gray', 'Brown', 'Black', 'Brown', 'Black', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Orange', 'Black', 'Black', 'Black', 'Orange', 'White', 'White', 'Orange', 'Brown', 'White', 'Orange', 'Black', 'White', 'Black', 'White', 'White', 'White', 'Orange', 'Orange', 'Gray', 'Gray', 'Gray', 'Black', 'Brown', 'Orange', 'Orange', 'Orange', 'Orange', 'Black', 'Black', 'Brown', 'White', 'Orange', 'Orange', 'Black', 'Brown', 'Brown', 'Gray', 'Brown', 'Brown', 'White', 'Black', 'Gray', 'Orange', 'Orange', 'Orange', 'White', 'White', 'Brown', 'Gray', 'Black', 'Gray', 'White', 'Gray', 'Orange', 'Orange', 'Black', 'White', 'Orange', 'Black', 'Orange', 'Gray', 'Black', 'Gray', 'Brown', 'White', 'Orange', 'Brown', 'Black', 'Black', 'Gray', 'Orange', 'Gray', 'White', 'Orang
# ...

# %%
dog2[0] == 'Orange'
# Out:
# True

# %%
dorange = []
dbrown = []
dwhite = []
dgray = []
dblack = []
for i in range(522):
    if dog2[i] == 'Orange':
        dorange.append(dogtime[i])
        print(int(dogtime[i]))
    elif dog2[i] == 'Brown':
        dbrown.append(int(dogtime[i]))
    elif dog2[i] == 'Black':
        dblack.append(int(dogtime[i]))
    elif dog2[i] == 'White':
        dwhite.append(int(dogtime[i]))
    elif dog2[i] == 'Gray':
        dgray.append(int(dogtime[i]))
    else:
        print("hello")
# Out:
# 85
# 43
# 63
# 17
# 17
# 1
# 47
# 65
# 12
# 10
# 61
# 89
# 50
# 31
# 45
# 66
# 7
# 14
# 49
# 9
# 14
# 75
# 44
# 16
# 82
# 72
# 82
# 39
# 57
# 42
# 32
# 35
# 61
# 79
# 42
# 24
# 12
# 3
# 55
# 61
# 42
# 53
# 61
# 30
# 30
# 58
# 21
# 52
# 18
# 51
# 68
# 73
# 18
# 42
# 72
# 71
# 20
# 23
# 1
# 23
# 41
# 68
# 23
# 74
# 5
# 18
# 87
# 14
# 23
# 58
# 26
# 84
# 71
# 71
# 47
# 2
# 29
# 19
# 47
# 84
# 73
# 84
# 19
# 38
# 14
# 55
# 10
# 43
# 62
# 67
# 75
# 58
# 36
# 66
# 37
# 15
# 38
# 66

# %%
dog2[1]
# Out:
# 'Brown'

# %%
dwhite
# Out:
# []

# %%
DO = []
DB = []
DBl = []
DG = []
DW = []

# %%
for m in range(522):
    if dog2[m] == ""

# %%
SDO = sum(dorange)
ADO = SDO/len(dorange)

# %%
print(ADO)
# Out:
# 43.69387755102041
